# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install networkx
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (2.6.3)

# %%
# %pip install -q stellargraph[demos]==1.2.1
# Out:
#      |████████████████████████████████| 435 kB 14.7 MB/s
#      |████████████████████████████████| 482 kB 33.6 MB/s
#      |████████████████████████████████| 462 kB 58.2 MB/s
#      |████████████████████████████████| 41 kB 384 kB/s
#   Building wheel for mplleaflet (setup.py) ... done

# %%
import stellargraph as sg

# %%
import pandas as pd
import os

import stellargraph as sg
from stellargraph.mapper import FullBatchNodeGenerator
from stellargraph.layer import GCN

from tensorflow.keras import layers, optimizers, losses, metrics, Model
from sklearn import preprocessing, model_selection
from IPython.display import display, HTML
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping

# %matplotlib inline

# %% [markdown]
# #### Loading CORA Dataset

# %%
dataset = sg.datasets.Cora()
display(HTML(dataset.description))
G, node_subjects = dataset.load()
# Out:
# The Cora dataset consists of 2708 scientific publications classified into one of seven classes. The citation network consists of 5429 links. Each publication in the dataset is described by a 0/1-valued word vector indicating the absence/presence of the corresponding word from the dictionary. The dictionary consists of 1433 unique words.

# %%
print(G.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 2708, Edges: 5429
#
#  Node types:
#   paper: [2708]
#     Features: float32 vector, length 1433
#     Edge types: paper-cites->paper
#
#  Edge types:
#     paper-cites->paper: [5429]
#         Weights: all 1 (default)
#         Features: none

# %%
node_subjects.value_counts().to_frame()
# Out:
#                         subject
# Neural_Networks             818
# Probabilistic_Methods       426
# Genetic_Algorithms          418
# Theory                      351
# Case_Based                  298
# Reinforcement_Learning      217
# Rule_Learning               180

# %% [markdown]
# #### Preparing Train and test data

# %%
train_subjects, test_subjects = model_selection.train_test_split(
    node_subjects, train_size=140, test_size=None, stratify=node_subjects
)
val_subjects, test_subjects = model_selection.train_test_split(
    test_subjects, train_size=500, test_size=None, stratify=test_subjects
)

# %%
train_subjects.value_counts().to_frame()
# Out:
#                         subject
# Neural_Networks              42
# Probabilistic_Methods        22
# Genetic_Algorithms           22
# Theory                       18
# Case_Based                   16
# Reinforcement_Learning       11
# Rule_Learning                 9

# %%
target_encoding = preprocessing.LabelBinarizer()

train_targets = target_encoding.fit_transform(train_subjects)
val_targets = target_encoding.transform(val_subjects)
test_targets = target_encoding.transform(test_subjects)

# %%
generator = FullBatchNodeGenerator(G, method="gcn")
train_gen = generator.flow(train_subjects.index, train_targets)
val_gen = generator.flow(val_subjects.index, val_targets)
test_gen = generator.flow(test_subjects.index, test_targets)
# Out:
# Using GCN (local pooling) filters...

# %% [markdown]
# #### Hyperparameter tuning

# %%
lrGCN = [0.005, 0.01]
layersGCN = [
          [16],
          [32],
          [64], [128], [16, 16], [32, 32], [64, 64], [16, 16, 16], [32, 32, 32], [64, 64, 64]
]

dropoutGCN = [0.2, 0.5, 0.7]

# %%
import tensorflow as tf
import pandas as pd

df_results = pd.DataFrame({'LR' : [], 'Layers': [], 'Dropout': [], 'ValAcc': []})

# %%
def getResults(lr, layer, dropout):
  activation = []
  for i in range(len(layer)):
    activation.append("relu")

  gcn = GCN(
    layer_sizes=layer, activations=activation, generator=generator, dropout=dropout
  )

  x_inp, x_out = gcn.in_out_tensors()

  predictions = layers.Dense(units=train_targets.shape[1], activation="softmax")(x_out)
  model = Model(inputs=x_inp, outputs=predictions)

  model.compile(
      optimizer=optimizers.Adam(lr=lr),
      loss=losses.categorical_crossentropy,
      metrics=["acc"],
  )

  es_callback = EarlyStopping(monitor="val_acc", patience=50, restore_best_weights=True)

  history = model.fit(
      train_gen,
      epochs=50,
      validation_data=val_gen,
      verbose=0,
      shuffle=False,  # this should be False, since shuffling data means shuffling the whole graph
      callbacks=[es_callback],
  )

  # sg.utils.plot_history(history)

  val_metrics = model.evaluate(val_gen)
  val_acc = model.evaluate(val_gen)[1]
  

  df2 = {'LR': lr, 'Layers': layer, 'Dropout': dropout, 'ValAcc': val_acc}
  df_results.append(df2, ignore_index=True)

  print("LR: {}, Layers: {}, Dropout: {}".format(lr, layer, dropout))
  print("Validation accuracy: ", val_acc)
  tf.keras.backend.clear_session()

# %%
iteration = 1
for l in lrGCN:
  for layer in layersGCN:
    for drop in dropoutGCN:
      print("Iteration : {}".format(iteration))
      getResults(l, layer, drop)
      iteration+= 1
# Out:
# Iteration : 1
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 1/1 [==============================] - 0s 72ms/step - loss: 0.8105 - acc: 0.7520
# 1/1 [==============================] - 0s 80ms/step - loss: 0.8105 - acc: 0.7520
# LR: 0.005, Layers: [16], Dropout: 0.2
# Validation accuracy:  0.7519999742507935
# Iteration : 2
# 1/1 [==============================] - 0s 76ms/step - loss: 0.7500 - acc: 0.7680
# 1/1 [==============================] - 0s 79ms/step - loss: 0.7500 - acc: 0.7680
# LR: 0.005, Layers: [16], Dropout: 0.5
# Validation accuracy:  0.7680000066757202
# Iteration : 3
# 1/1 [==============================] - 0s 78ms/step - loss: 0.7807 - acc: 0.7720
# 1/1 [==============================] - 0s 72ms/step - loss: 0.7807 - acc: 0.7720
# LR: 0.005, Layers: [16], Dropout: 0.7
# Validation accuracy:  0.7720000147819519
# Iteration : 4
# 1/1 [==============================] - 0s 73ms/step - loss: 0.6794 - acc: 0.7760
# 1/1 [==============================] - 0s 78ms/step - loss: 0.6794 - acc: 0.7760
# LR: 0.005, Layers: [32], Dropout: 0.2
# Validation accuracy:  0.7760000228881836
# Iteration : 5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.6829 - acc: 0.7820
# 1/1 [==============================] - 0s 84ms/step - loss: 0.6829 - acc: 0.7820
# LR: 0.005, Layers: [32], Dropout: 0.5
# Validation accuracy:  0.7820000052452087
# Iteration : 6
# 1/1 [==============================] - 0s 76ms/step - loss: 0.7100 - acc: 0.7720
# 1/1 [==============================] - 0s 81ms/step - loss: 0.7100 - acc: 0.7720
# LR: 0.005, Layers: [32], Dropout: 0.7
# Validation accuracy:  0.7720000147819519
# Iteration : 7
# 1/1 [==============================] - 0s 81ms/step - loss: 0.6654 - acc: 0.7900
# 1/1 [==============================] - 0s 89ms/step - loss: 0.6654 - acc: 0.7900
# LR: 0.005, Layers: [64], Dropout: 0.2
# Validation accuracy:  0.7900000214576721
# Iteration : 8
# 1/1 [==============================] - 0s 72ms/step - loss: 0.6361 - acc: 0.8000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.6361 - acc: 0.8000
# LR: 0.005, Layers: [64], Dropout: 0.5
# Validation accuracy:  0.800000011920929
# Iteration : 9
# 1/1 [==============================] - 0s 74ms/step - loss: 0.6275 - acc: 0.8000
# 1/1 [==============================] - 0s 82ms/step - loss: 0.6275 - acc: 0.8000
# LR: 0.005, Layers: [64], Dropout: 0.7
# Validation accuracy:  0.800000011920929
# Iteration : 10
# 1/1 [==============================] - 0s 85ms/step - loss: 0.7280 - acc: 0.7860
# 1/1 [==============================] - 0s 99ms/step - loss: 0.7280 - acc: 0.7860
# LR: 0.005, Layers: [128], Dropout: 0.2
# Validation accuracy:  0.7860000133514404
# Iteration : 11
# 1/1 [==============================] - 0s 88ms/step - loss: 0.6835 - acc: 0.8000
# 1/1 [==============================] - 0s 84ms/step - loss: 0.6835 - acc: 0.8000
# LR: 0.005, Layers: [128], Dropout: 0.5
# Validation accuracy:  0.800000011920929
# Iteration : 12
# 1/1 [==============================] - 0s 90ms/step - loss: 0.6895 - acc: 0.7980
# 1/1 [==============================] - 0s 99ms/step - loss: 0.
# 1/1 [==============================] - 0s 71ms/step - loss: 1.3428 - acc: 0.7840
# LR: 0.01, Layers: [16, 16, 16], Dropout: 0.2
# Validation accuracy:  0.7839999794960022
# Iteration : 53
# 1/1 [==============================] - 0s 67ms/step - loss: 0.9817 - acc: 0.8140
# 1/1 [==============================] - 0s 70ms/step - loss: 0.9817 - acc: 0.8140
# LR: 0.01, Layers: [16, 16, 16], Dropout: 0.5
# Validation accuracy:  0.8140000104904175
# Iteration : 54
# 1/1 [==============================] - 0s 72ms/step - loss: 0.9914 - acc: 0.6860
# 1/1 [==============================] - 0s 79ms/step - loss: 0.9914 - acc: 0.6860
# LR: 0.01, Layers: [16, 16, 16], Dropout: 0.7
# Validation accuracy:  0.6859999895095825
# Iteration : 55
# 1/1 [==============================] - 0s 68ms/step - loss: 2.2542 - acc: 0.7940
# 1/1 [==============================] - 0s 74ms/step - loss: 2.2542 - acc: 0.7940
# LR: 0.01, Layers: [32, 32, 32], Dropout: 0.2
# Validation accuracy:  0.7940000295639038
# Iteration : 56
# 1/1 [==============================] - 0s 74ms/step - loss: 1.1912 - acc: 0.8260
# 1/1 [==============================] - 0s 68ms/step - loss: 1.1912 - acc: 0.8260
# LR: 0.01, Layers: [32, 32, 32], Dropout: 0.5
# Validation accuracy:  0.8259999752044678
# Iteration : 57
# 1/1 [==============================] - 0s 75ms/step - loss: 0.8230 - acc: 0.8180
# 1/1 [==============================] - 0s 77ms/step - loss: 0.8230 - acc: 0.8180
# LR: 0.01, Layers: [32, 32, 32], Dropout: 0.7
# Validation accuracy:  0.8180000185966492
# Iteration : 58
# 1/1 [==============================] - 0s 74ms/step - loss: 4.0653 - acc: 0.7940
# 1/1 [==============================] - 0s 75ms/step - loss: 4.0653 - acc: 0.7940
# LR: 0.01, Layers: [64, 64, 64], Dropout: 0.2
# Validation accuracy:  0.7940000295639038
# Iteration : 59
# 1/1 [==============================] - 0s 79ms/step - loss: 2.2058 - acc: 0.8240
# 1/1 [==============================] - 0s 69ms/step - loss: 2.2058 - acc: 0.8240
# LR: 0.01, Layers: [64, 64, 64], Dropout: 0.5
# Validation accuracy:  0.8240000009536743
# Iteration : 60
# 1/1 [==============================] - 0s 91ms/step - loss: 1.1533 - acc: 0.8160
# 1/1 [==============================] - 0s 81ms/step - loss: 1.1533 - acc: 0.8160
# LR: 0.01, Layers: [64, 64, 64], Dropout: 0.7
# Validation accuracy:  0.8159999847412109

# %%
gcn = GCN(
  layer_sizes=[32, 32], activations=["relu", "relu"], generator=generator, dropout=0.7
)

x_inp, x_out = gcn.in_out_tensors()

predictions = layers.Dense(units=train_targets.shape[1], activation="softmax")(x_out)
model = Model(inputs=x_inp, outputs=predictions)

model.compile(
    optimizer=optimizers.Adam(lr=0.005),
    loss=losses.categorical_crossentropy,
    metrics=["acc"],
)

es_callback = EarlyStopping(monitor="val_acc", patience=50, restore_best_weights=True)

history = model.fit(
    train_gen,
    epochs=200,
    validation_data=val_gen,
    verbose=0,
    shuffle=False,  # this should be False, since shuffling data means shuffling the whole graph
    callbacks=[es_callback],
)

# sg.utils.plot_history(history)

val_metrics = model.evaluate(val_gen)
val_acc = model.evaluate(val_gen)[1]
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 1/1 [==============================] - 0s 116ms/step - loss: 0.5666 - acc: 0.8520
# 1/1 [==============================] - 0s 121ms/step - loss: 0.5666 - acc: 0.8520

# %%
test_acc = model.evaluate(test_gen)[1]
# Out:
# 1/1 [==============================] - 0s 120ms/step - loss: 0.6378 - acc: 0.8259
